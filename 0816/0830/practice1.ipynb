# %%
total = 0
total += 1
total += 2
total += 3
total += 4
total += 5
total += 6
total += 7
total += 8
total += 9
total += 10
print(total)
# Out:
# 55

# %%
total = 0
for n in range(1, 101):
    #print(f"n={n}")
    total += n
print(total)
# Out:
# 5050
